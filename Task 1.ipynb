# %% [markdown]
# Name - Aayush Singh
# Course - Data Science

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns

# %%
df=pd.read_csv('Titanic-Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#to check if there are any null values or not in data
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#dropping cabin column since it has more NAN values than half of the total rows
df=df.drop(columns="Cabin", axis=1)

# %%
#print without cabin column
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Since from above we can see that there are still some NAN values in Age column
#adding mean values in that places
df["Age"].fillna(df["Age"].mean(), inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
#count row have 891 values in each columns that means no more NaN values
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
#there are some NaN values in Embarked column too
#when I used df.isnull().sum() in above
#replacing NaN values with mode of Embarked
df['Embarked'].fillna('S', inplace=True)

# %%
#checking if there are any more column with NaN values
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# The data has become clean now.

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Now we will be analyzing the passenger that survived according to different categories.

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#1 for Survived and 0 for Not Survived
#printing graph displaying graph of survived and not survived
sns.countplot(data=df,x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# Showing Graph of passsengers that travelled and how many of them survived according to Pclass

# %%
#plotting graph of people showing their class of travelling
# 1 - upper
# 2 - middle
# 3 - lower
sns.countplot(data=df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#graph showing survived and not survived according to Pclass
#basically showing how many non survivers and surviviers from each of the Pclass
#0- non survived and 1-survived
sns.countplot(x=df['Survived'], hue=df['Pclass'])
plt.show()

# %% [markdown]
# Showing Graph of passsengers that travelled and how many of them survived according to Gender

# %%
#plotting graph for showing passengers genders that travelled
sns.countplot(data=df,x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#graph showing survived and not survived according to Gender
#basically showing how many non survivers and surviviers from each of the Gender
#0- non survived and 1-survived
sns.countplot(x=df['Survived'], hue=df['Sex'])
plt.show()

# %% [markdown]
# Showing Graph how many of passsengers that travelled survived according to Age

# %%
#plotting graph for showing passengers age that travelled
sns.countplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
#graph showing survived and not survived according to Age
#basically showing how many non survivers and surviviers from each of the Age
#0- non survived and 1-survived
sns.histplot(x=df['Age'], hue=df['Survived'], multiple='stack')
plt.show()

# %% [markdown]
# Showing Graph of passsengers that travelled and how many of them survived according to Embarked

# %%
#plotting graph for showing passengers age that travelled
sns.countplot(data=df,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
#graph showing survived and not survived according to Embarked
#basically showing how many non survivers and surviviers from each of the Embarked
#0- non survived and 1-survived
sns.countplot(x=df['Survived'], hue=df['Embarked'])
plt.show()

# %% [markdown]
# Showing Graph how many of passsengers that travelled survived according to Fare

# %%
#graph showing survived and not survived according to Fare
#basically showing how many non survivers and surviviers from each of the Fare
#0- non survived and 1-survived
sns.histplot(x=df['Fare'], hue=df['Survived'], multiple='stack')
plt.show()

# %% [markdown]
# We have completed analysing data.

# %% [markdown]
# Now we will convert gender/Sex values in numericals instead of male and females

# %%
#converting male and female values in Sex column with 1 and 0
# 1 - male
# 0 - female
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Sex'] = labelencoder.fit_transform(df['Sex'])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
#now checking the change in the
#graph showing survived and not survived according to Gender
#basically showing how many non survivers and surviviers from each of the Gender
#0- non survived and 1-survived
sns.countplot(x=df['Survived'], hue=df['Sex'])
plt.show()

# %% [markdown]
# Removing unnecessary columns from data

# %%
df.drop(columns=["PassengerId","Name","SibSp","Parch","Ticket","Fare","Age", "Embarked"],inplace=True)

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex
# count  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587
# std      0.486592    0.836071    0.477990
# min      0.000000    1.000000    0.000000
# 25%      0.000000    2.000000    0.000000
# 50%      0.000000    3.000000    1.000000
# 75%      1.000000    3.000000    1.000000
# max      1.000000    3.000000    1.000000

# %% [markdown]
# Data Modeling

# %% [markdown]
# Splitting the above data into test and train

# %%
#by using sklearn library
from sklearn.model_selection import train_test_split
X=df[['Sex', 'Pclass']]
Y=df['Survived']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# Here I am using Logistic Regression Model.
# Note- You can use different ways other than 'Logistic Regression Model' to create this model.

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Making Prediction on testing set

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# Evaluating the accuracy

# %%
accuracy = accuracy_score(Y_test, Y_pred)
print(f"Accuracy: {accuracy:.3f}")
print(f"Classification Report:\n{classification_report(Y_test, Y_pred)}")
print(f"Confusion Matrix:\n{confusion_matrix(Y_test, Y_pred)}")
# Out:
# Accuracy: 0.782
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       105
#            1       0.75      0.70      0.73        74
#
#     accuracy                           0.78       179
#    macro avg       0.78      0.77      0.77       179
# weighted avg       0.78      0.78      0.78       179
#
# Confusion Matrix:
# [[88 17]
#  [22 52]]

# %%
Y_test
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
#       ..
# 433    0
# 773    0
# 25     1
# 84     1
# 10     1
# Name: Survived, Length: 179, dtype: int64

# %%
submission=X.iloc[:,:].values
y_final=model.predict(submission)
y_final.shape
# Out:
# (891,)

# %%
final = pd.DataFrame()
final["Sex"]= X['Sex']
final["survived"]=y_final

# %%
import warnings
warnings.filterwarnings("ignore")
result = model.predict([[5,0]])
if(result == 0):
    print("So soory, Not Survived")
else:
    print("Survived")
# Out:
# So soory, Not Survived
